# %%
import xgboost as xgb
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# /Users/jerry/anaconda3/lib/python3.7/site-packages/dask/config.py:168: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   data = yaml.load(f.read()) or {}
# /Users/jerry/anaconda3/lib/python3.7/site-packages/distributed/config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
train = pd.read_csv('/Users/jerry/Desktop/udemy courses/Kaggle数据分析/Avito Duplicate Ads Detection/train.csv')

# %%
train1 = train.drop(['locationID_x.1','locationID_y.1','categoryID_x.1','categoryID_y.1'],axis = 1)

# %%
train1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991396 entries, 0 to 2991395
# Data columns (total 31 columns):
# Unnamed: 0            int64
# itemID_1              int64
# itemID_2              int64
# isDuplicate           int64
# generationMethod      int64
# itemID_x              int64
# categoryID_x          int64
# title_x               object
# description_x         object
# images_array_x        object
# attrsJSON_x           object
# price_x               float64
# locationID_x          int64
# metroID_x             float64
# lat_x                 float64
# lon_x                 float64
# itemID_y              int64
# categoryID_y          int64
# title_y               object
# description_y         object
# images_array_y        object
# attrsJSON_y           object
# price_y               float64
# locationID_y          int64
# metroID_y             float64
# lat_y                 float64
# lon_y                 float64
# regionID_x            int64
# regionID_y            int64
# parentCategoryID_x    int64
# parentCategoryID_y    int64
# dtypes: float64(8), int64(15), object(8)
# memory usage: 707.5+ MB

# %% [markdown]
# Classification Models: LDA, QDA, Logistic regression, SVM, Decision Trees, Random Forests, various forms of Boosting

# %% [markdown]
# # 1 Tree based methods

# %% [markdown]
# ## 1.1 Decision Tree

# %%
#metroID有太多 missing data
#title, attrsJSON, description 不是英文
#images 暂时不用
#item id 重复了 

#'title_x','title_y', 'description_x', 'description_y'  尝试用一下
train2 = train1.drop(['Unnamed: 0',  'images_array_x',
                      'images_array_y', 'attrsJSON_x', 'attrsJSON_y', 'generationMethod', 'metroID_x', 
                      'metroID_y','itemID_x', 'itemID_y'], axis=1)

# %%
train2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991396 entries, 0 to 2991395
# Data columns (total 21 columns):
# itemID_1              int64
# itemID_2              int64
# isDuplicate           int64
# categoryID_x          int64
# title_x               object
# description_x         object
# price_x               float64
# locationID_x          int64
# lat_x                 float64
# lon_x                 float64
# categoryID_y          int64
# title_y               object
# description_y         object
# price_y               float64
# locationID_y          int64
# lat_y                 float64
# lon_y                 float64
# regionID_x            int64
# regionID_y            int64
# parentCategoryID_x    int64
# parentCategoryID_y    int64
# dtypes: float64(6), int64(11), object(4)
# memory usage: 479.3+ MB

# %%
train3 = train2.dropna()
train3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2651916 entries, 0 to 2991395
# Data columns (total 21 columns):
# itemID_1              int64
# itemID_2              int64
# isDuplicate           int64
# categoryID_x          int64
# title_x               object
# description_x         object
# price_x               float64
# locationID_x          int64
# lat_x                 float64
# lon_x                 float64
# categoryID_y          int64
# title_y               object
# description_y         object
# price_y               float64
# locationID_y          int64
# lat_y                 float64
# lon_y                 float64
# regionID_x            int64
# regionID_y            int64
# parentCategoryID_x    int64
# parentCategoryID_y    int64
# dtypes: float64(6), int64(11), object(4)
# memory usage: 445.1+ MB

# %%
train3.head(5)
# Out:
#    itemID_1  itemID_2  isDuplicate  categoryID_x  \
# 0         1   4112648            1            81
# 1         3   1991275            1            14
# 2         4   1223296            0            84
# 3         7   1058851            1            84
# 4         8   2161930            1            39
#
#                                title_x  \
# 0                    Продам Камаз 6520
# 1                            Yamaha r6
# 2                       iPhone 3gs 8gb
# 3  Xiaomi Mi4 3гб RAM + 16гб ROM белый
# 4                       Лыжные ботинки
#
#                                        description_x   price_x  locationID_x  \
# 0                          Продам Камаз 6520 20 тонн  300000.0        648140
# 1                                    Весь в тюнинге.  300000.0        639040
# 2  Телефон в хорошем состоянии, трещин и сколов н...    3500.0        640650
# 3  Отличный подарок на новый год от "китайской ap...   13500.0        662210
# 4      Лыжные ботинки в хорошем состоянии, 34 размер     500.0        624360
#
#        lat_x      lon_x  ...                                       title_y  \
# 0  64.686946  30.815924  ...                             Продам Камаз 6520
# 1  55.678037  37.256548  ...                                     Yamaha R6
# 2  56.239398  43.460458  ...                               iPhone 3gs 32gb
# 3  55.777170  37.586194  ...  Смартфон Xiaomi Mi4 3гб RAM + 16гб ROM белый
# 4  55.777170  37.586194  ...                               Ботинки для лыж
#
#                                        description_y   price_y  locationID_y  \
# 0                          Продам Камаз 6520 20 тонн  300000.0        648140
# 1                      Весь в тюнинге. Возможен торг  330000.0        639040
# 2  В отличном состоянии, в комплекте зарядник и к...    3500.0        640650
# 3  Отличный подарок на новый год от "китайской ap...   13500.0        662210
# 4             Ботинки 34 размер, в хорошем состоянии     600.0        624360
#
#        lat_y      lon_y  regionID_x  regionID_y  parentCategoryID_x  \
# 0  64.686946  30.815924      648070      648070                   1
# 1  55.678037  37.256548      637680      637680                   1
# 2  56.239398  43.460458      640310      640310                   6
# 3  56.135459  47.235484      662000      662000                   6
# 4  55.777170  37.586194      624300      624300                   7
#
#    parentCategoryID_y
# 0                   1
# 1                   1
# 2                   6
# 3                   6
# 4                   7
#
# [5 rows x 21 columns]

# %%
train3.isna().sum()
# Out:
# itemID_1              0
# itemID_2              0
# isDuplicate           0
# categoryID_x          0
# title_x               0
# description_x         0
# price_x               0
# locationID_x          0
# lat_x                 0
# lon_x                 0
# categoryID_y          0
# title_y               0
# description_y         0
# price_y               0
# locationID_y          0
# lat_y                 0
# lon_y                 0
# regionID_x            0
# regionID_y            0
# parentCategoryID_x    0
# parentCategoryID_y    0
# dtype: int64

# %%
#如何两个商品是一样的，那么price,location,lat,lon,category,region,parentcategory
#所以相减 看一下结果是不是0
import math 

y = train3.isDuplicate

price = abs(train3.price_x - train3.price_y)/train3[["price_x", "price_y"]].min(axis=1)
location = 1*(train3.locationID_x == train3.locationID_y)

lat = abs(train3.lat_x - train3.lat_y)
lon = abs(train3.lon_x - train3.lon_y)
distance = (lat**2 + lon**2)**(.5)

description = 1*(train3.description_x == train3.description_y)
title = 1*(train3.title_x == train3.title_y)
category = 1*(train3.categoryID_x == train3.categoryID_y)
region = 1*(train3.regionID_x == train3.regionID_y)
parentCategory = 1*(train3.parentCategoryID_x == train3.parentCategoryID_y)


d = {'price': price, 'location': location, 
     'distance':distance,
     'description':description, 'title':title, 
     'category': category, 'region': region, 'parentCategory': parentCategory}
X = pd.DataFrame(data=d)

# %%
X.head()
# Out:
#    price  location  distance  description  title  category  region  \
# 0    0.0         1   0.00000            1      1         1       1
# 1    0.1         1   0.00000            0      0         1       1
# 2    0.0         1   0.00000            0      0         1       1
# 3    0.0         1   9.65594            0      0         1       1
# 4    0.2         1   0.00000            0      0         1       1
#
#    parentCategory
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
y = train3[['isDuplicate']]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33)
from sklearn.tree import DecisionTreeClassifier
dtree = DecisionTreeClassifier()
model = dtree.fit(X_train,y_train)

# %%
prediction = model.predict(X_test)

# %%
prediction
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
from sklearn.metrics import classification_report, confusion_matrix

# %%
print(confusion_matrix(y_test, prediction))
# Out:
# [[371317 143642]
#  [106495 253679]]

# %%
print(classification_report(y_test, prediction))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75    514959
#            1       0.64      0.70      0.67    360174
#
#    micro avg       0.71      0.71      0.71    875133
#    macro avg       0.71      0.71      0.71    875133
# weighted avg       0.72      0.71      0.72    875133

# %% [markdown]
# We have a pretty good prediction already for the decision tree with high precision.

# %% [markdown]
# ## 1.2 Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier(n_estimators = 50)

# %%
rfc.fit(X_train, y_train)
# Out:
# /Users/jerry/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
rfc_pred = rfc.predict(X_test)

# %%
print(confusion_matrix(y_test, rfc_pred))
# Out:
# [[369953 145006]
#  [102649 257525]]

# %%
print(classification_report(y_test, rfc_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.72      0.75    514959
#            1       0.64      0.72      0.68    360174
#
#    micro avg       0.72      0.72      0.72    875133
#    macro avg       0.71      0.72      0.71    875133
# weighted avg       0.72      0.72      0.72    875133

# %% [markdown]
# There is no huge improvement over the simple decision tree but random forest is still a bit better.

# %%
rfc_pred_prob = rfc.predict_proba(X_test)[:,1]

# %%
import numpy as np
from sklearn import metrics

# %%
y_test1 = np.array(y_test['isDuplicate'])
y_test1
# Out:
# array([0, 0, 1, ..., 0, 1, 0])

# %%
rfc_pred_prob1 = np.array(rfc_pred_prob)
rfc_pred_prob1
# Out:
# array([0.05      , 0.0793466 , 0.52764447, ..., 0.2443473 , 0.52764447,
#        0.18756787])

# %%
fpr, tpr, thresholds = metrics.roc_curve(y_test1, rfc_pred_prob1)
metrics.auc(fpr, tpr)
# Out:
# 0.7866579324044078

# %% [markdown]
# # Test Data

# %%
test = pd.read_csv('/Users/jerry/Desktop/udemy courses/Kaggle数据分析/Avito Duplicate Ads Detection/test.csv')

# %%
test1 = test.drop(['locationID_x.1','locationID_y.1','categoryID_x.1','categoryID_y.1'],axis = 1)

# %%
test2 = test1.drop(['Unnamed: 0','images_array_x',
                      'images_array_y', 'attrsJSON_x', 'attrsJSON_y', 'metroID_x', 
                      'metroID_y','itemID_x', 'itemID_y'], axis=1)

# %%
test2.head()
# Out:
#    id  itemID_1  itemID_2  categoryID_x  \
# 0   0         5   4670875           115
# 1   1         5    787210           115
# 2   2         6   1705280            10
# 3   3        11   3020777           101
# 4   4        23   5316130            27
#
#                                             title_x  \
# 0            Сотрудничество салонам кухонной мебели
# 1            Сотрудничество салонам кухонной мебели
# 2                                    Радар-детектор
# 3                       Зарядка для ноутбука Lenovo
# 4  Кожаная opигинaльнaя куpткa- "косyxa" -Roundtree
#
#                                        description_x  price_x  locationID_x  \
# 0  Сотрудничество салонам кухонной мебели.\nТребу...      NaN        637640
# 1  Сотрудничество салонам кухонной мебели.\nТребу...      NaN        637640
# 2  Продам радар-детектор в идеальном состоянии!Пр...      NaN        637160
# 3  Зарядное устройство для ноутбука Lenovo, (19v,...   1300.0        650400
# 4  Бренд:  Roundtree & Yorke®\nMoдель:  Heritage ...  15000.0        637640
#
#        lat_x      lon_x  ...                                         title_y  \
# 0  55.760211  37.577211  ...  Сотрудничество агенствам недвижимости в Москве
# 1  55.760211  37.577211  ...  Сотрудничество агенствам недвижимости в москве
# 2  59.645846  33.513035  ...                                  Радар-детектор
# 3  55.817608  49.097646  ...                      Б у батарейки для ноутбука
# 4  55.827080  37.437604  ...   Кожаная кypткa- "кocyxa" -Roundtrее-And-Yоrkе
#
#                                        description_y  price_y  locationID_y  \
# 0    Сотрудничество агенствам недвижимости в МОСКВЕ.      NaN        637640
# 1    Сотрудничество агенствам недвижимости в МОСКВЕ.      NaN        637640
# 2  Продам радар-детектор в идеальном состоянии! П...   1500.0        637160
# 3  б у батарейки. отправка по рФ. Звоните с 10-00...    490.0        650400
# 4  Бренд:  Roundtree & Yorke®\nMoдель:  Heritage ...  15000.0        637640
#
#        lat_y      lon_y  regionID_x  regionID_y  parentCategoryID_x  \
# 0  55.760211  37.577211      637640      637640                 113
# 1  55.760211  37.577211      637640      637640                 113
# 2  59.645846  33.513035      636370      636370                   1
# 3  55.817608  49.097646      650130      650130                   6
# 4  55.827080  37.437604      637640      637640                   5
#
#    parentCategoryID_y
# 0                 113
# 1                 113
# 2                   1
# 3                   6
# 4                   5
#
# [5 rows x 21 columns]

# %%
test2.isna().sum()
# Out:
# id                         0
# itemID_1                   0
# itemID_2                   0
# categoryID_x               0
# title_x                    2
# description_x             25
# price_x               129371
# locationID_x               0
# lat_x                      0
# lon_x                      0
# categoryID_y               0
# title_y                    0
# description_y             24
# price_y               129700
# locationID_y               0
# lat_y                      0
# lon_y                      0
# regionID_x                 0
# regionID_y                 0
# parentCategoryID_x         0
# parentCategoryID_y         0
# dtype: int64

# %%
test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044196 entries, 0 to 1044195
# Data columns (total 21 columns):
# id                    1044196 non-null int64
# itemID_1              1044196 non-null int64
# itemID_2              1044196 non-null int64
# categoryID_x          1044196 non-null int64
# title_x               1044194 non-null object
# description_x         1044171 non-null object
# price_x               914825 non-null float64
# locationID_x          1044196 non-null int64
# lat_x                 1044196 non-null float64
# lon_x                 1044196 non-null float64
# categoryID_y          1044196 non-null int64
# title_y               1044196 non-null object
# description_y         1044172 non-null object
# price_y               914496 non-null float64
# locationID_y          1044196 non-null int64
# lat_y                 1044196 non-null float64
# lon_y                 1044196 non-null float64
# regionID_x            1044196 non-null int64
# regionID_y            1044196 non-null int64
# parentCategoryID_x    1044196 non-null int64
# parentCategoryID_y    1044196 non-null int64
# dtypes: float64(6), int64(11), object(4)
# 140                  Все типы отделочных и ремонтных работ
# 141                  Все типы отделочных и ремонтных работ
# 142                            Продам фары на Datsun ON-DO
# 150             Зарядка для Nokia(обмен, отправляю почтой)
# ...                                                    ...
# 1043967                           Профлист сс10-1165 оцинк
# 1043974                                        Круз бампер
# 1043983                         Продаю запчасти камаз, маз
# 1043988                                             Мтз-80
# 1044010                           Отдам кота в добрые руки
# 1044027                                   Услуги электрика
# 1044028                 В добрые руки замечательную собаку
# 1044031                                Сделаем ремонт евро
# 1044033                                  Инженер-геодезист
# 1044045                               Сварщик 3-го разряда
# 1044046                        Укладка керамической плитки
# 1044055                      Мебель, стулья, столы, комоды
# 1044056                                 Ремонт Компьютеров
# 1044059                                  Работник с опытом
# 1044072                              Запчасти авто газ ВАЗ
# 1044085                                             Хотошо
# 1044087                           Станок токарный бу 16к20
# 1044105       Деревенская картошка с доставкой до квартиры
# 1044106                                           Шугаринг
# 1044110                                    Комбенизон ёмаё
# 1044112                                 Куплю 1-к квартиру
# 1044114                               Туфли с бантом даром
# 1044117                             Рассмотрю все варианты
# 1044123                                              Пушок
# 1044142                                             Платье
# 1044148                                             Хотошо
# 1044161  Котик вислоухий(фолд) окрас черное пятно на се...
# 1044163                                 Продаются кофточки
# 1044173                            Подсобный, разнорабочий
# 1044179                                     Peg Perego gt3
#
#                                              description_x  price_x  \
# 0        Сотрудничество салонам кухонной мебели.\nТребу...      NaN
# 1        Сотрудничество салонам кухонной мебели.\nТребу...      NaN
# 2        Продам радар-детектор в идеальном состоянии!Пр...      NaN
# 6        Кама евро 129 на штамповках. в нормальном сост...      NaN
# 8        1)Battlefield hardline-1000р.(PS3).\n2)Стартре...      NaN
# 21       Качественно и не дорого выложу плитку любой сл...      NaN
# 22       Качественно и не дорого выложу плитку любой сл...      NaN
# 23       Качественно и не дорого выложу плитку любой сл...      NaN
# 24       Качественно и не дорого выложу плитку любой сл...      NaN
# 25       Качественно и не дорого выложу плитку любой сл...      NaN
# 26       Качественно и не дорого выложу плитку любой сл...      NaN
# 30                                              Ищу работу      NaN
# 45       Исполнительный, пунктуальный, готовый много уч...      NaN
# 52       Знание запчастей к автомобилям МАЗ, КАМАЗ, ГАЗ...      NaN
# 55       Отдам щенка( кабель) 7 месяцев,окрас шоколадны...      NaN
# 61       Ремонт Велосипедов,регулировка,настройка,диагн...      NaN
# 62       ООО "Производство Резервуарного Оборудования" ...      NaN
# 64       Разнорабочий\nПодсобник\nГрузчик\nРассмотрю вс...      NaN
# 70                                      продам на запчасти      NaN
# 88       Интиресуют любые варианты продажи и обмена.\nH...      NaN
# 98       Волох А.С.  Основы управления действием взрыва...      NaN
# 116      Продам срочно ноутбук новый брали за 72тыс пол...      NaN
# 120      Наращивание ногтей, гелем на формы! Любой диза...      NaN
# 126      Отдам щенков в добрые руки (4 девочки )  подар...      NaN
# 130      Женщина,55 лет,РФ.Живу в Нижнем Новгороде, Без...      NaN
# 131      Заброска туристов на все реки и озёра Лоухског...      NaN
# 140      Выполним все виды отделочных,ремонтных работ к...      NaN
# 141      Выполним все виды отделочных,ремонтных работ к...      NaN
# 142      Продаю фары и радиатор на автомобиль Datsun ON...      NaN
# 150      зарядка Nokia Универсальная AC-3E,подходит для...      NaN
# ...                                                    ...      ...
# 1043967  Предлагаем на заказ любой длины до 12м профнас...      NaN
# 1043974     круз бампера переднии и заднии возможно в цвет      NaN
# 1043983  продаю чулок передний,задний,балку переднюю,ре...      NaN
# 1043988  Продаю трактор МТЗ 80 в отличном состоянии 199...      NaN
# 1044010  Отдам кота в добрые руки.\nКоту 1 год,костриро...      NaN
# 1044027  ремонт и замена проводки , розеток, светильник...      NaN
# 1044028  Крупная девчушка, месяцев 7 от роду, с очень и...      NaN
# 1044031  Здравствуйте\nЕсть опытных мастеров\nСпециалис...      NaN
# 1044033  в настоящее время (с 2003) ИП, наличие парка и...      NaN
# 1044045   Без вредных привычек.Ручная дуговая,полуавтомат.      NaN
# 1044046  Требуется облицевать камин керамической плитко...      NaN
# 1044055  Стулья \nСтолы\nКомоды\nПуфики \nБанкетки \nДи...      NaN
# 1044056  Выполняю широкий спектр услуг по ремонту компь...      NaN
# 1044059  Русский молодой с опытом и умение работы на ст...      NaN
# 1044072  Волга\nДвигатель 406 27000руб\nПередние седени...      NaN
# 1044085  Щенки Хотошо (бурят-монгольский волкодав) чист...      NaN
# 1044087  Продажа токарных станков после проведенного ре...      NaN
# 1044105  ●▬▬▬▬▬▬ஜ۩۞۩ஜ▬▬▬▬▬▬▬●\n░░░░░►Картошка отборная ...      NaN
# 1044106            Студия Шугаринга .  Уссурийская 8,каб 5      NaN
# 1044110  Продам комбенизон для малышки Российской фирмы...      NaN
# 1044112  Куплю 1-2-х комнатную квартиру в любом районе ...      NaN
# 1044114  Добрый день! Отдам даром лиловые тфули с банто...      NaN
# 1044117  Не женат, детей нет, владею ПК свободно,  ВУ н...      NaN
# 1044123  Голубогазый красавчик от породистого папы. Оче...      NaN
# 1044142                           р-р 38-40. из трикотажа.      NaN
# 1044148  Щенки Хотошо (бурят-монгольский волкодав) чист...      NaN
# 1044161  Вислоухий котик(скоттиш фолд) окрас черное пят...      NaN
# 1044163  продаются кофточки в идеальном состояние. за в...      NaN
# 1044173     Шпаклевка,штукатурка,монтаж,гипсокартон и т.д.      NaN
# 1044179  Продаётся peg Perego gt3 прогулка дефект один ...      NaN
#
#          locationID_x      lat_x       lon_x  ...  \
# 0              637640  55.760211   37.577211  ...
# 1              637640  55.760211   37.577211  ...
# 2              637160  59.645846   33.513035  ...
# 6              650400  55.750109   49.207735  ...
# 8              653240  59.842110   30.250588  ...
# 21             650400  55.855851   49.084495  ...
# 22             650400  55.855851   49.084495  ...
# 23             650400  55.855851   49.084495  ...
# 24             650400  55.855851   49.084495  ...
# 25             650400  55.855851   49.084495  ...
# 26             650400  55.855851   49.084495  ...
# 30             635860  55.453085   65.346508  ...
# 45             648760  56.637263   47.886673  ...
# 52             632760  44.920647   41.079626  ...
# 55             661420  55.152161   61.387103  ...
# 61             632490  57.767256   40.926984  ...
# 62             638110  55.623937   37.843908  ...
# 64             655100  54.779800   31.999095  ...
# 70             656901  56.860477   35.904539  ...
# 88             633570  45.440068   40.557659  ...
# 1044031                       Мастер по малярный работы
# 1044033                               Инженер-геодезист
# 1044045                                         Сварщик
# 1044046                     Укладка керамической плитки
# 1044055                                          Комоды
# 1044056                              Ремонт компьютеров
# 1044059                                Рабочий с опытом
# 1044072                                        Запчасти
# 1044085                                          Хотошо
# 1044087                  Станок токарный 16К25 рмц 1000
# 1044105    Деревенская картошка с доставкой до квартиры
# 1044106                                        Шугаринг
# 1044110                                 Комбенезон Ёмаё
# 1044112                              Сниму 1-к квартиру
# 1044114                                 Ботильоны даром
# 1044117                          Рассмотрю все варианты
# 1044123                                   Ручные малыши
# 1044142                                         Рубашка
# 1044148                                          Хотошо
# 1044161     Вислоухий кот окрас черное пятно на серебре
# 1044163                  Продаются спортивки на девочку
# 1044173                            Грузчик-разнорабочий
# 1044179                                  Peg perego gt3
#
#                                              description_y price_y  \
# 0          Сотрудничество агенствам недвижимости в МОСКВЕ.     NaN
# 1          Сотрудничество агенствам недвижимости в МОСКВЕ.     NaN
# 2        Продам радар-детектор в идеальном состоянии! П...  1500.0
# 6        Кама 129 \n14 радиус 2 шт 175 на 70 и 2 шт 175...  4000.0
# 8        Naruto Storm 1.\nNaruto Storm 2.\nNaruto Storm...  4500.0
# 21       Качественно и не дорого выполню штукатурные и ...     NaN
# 22       Качественно и не дорого построим дом дачу баню...     NaN
# 23       Строительство бань под ключ . не дорого. По ва...     NaN
# 24       Если вы строите дом дачу баню или ремонт кварт...     NaN
# 25       Качественно и не дорого выложу плитку любой сл...     NaN
# 26       Качественно и не дорого выложу плитку , природ...     NaN
# 30       Бригада из 3-4 чел. ищет работу по строительст...     NaN
# 45       Исполнительный, пунктуальный, готовый много уч...     NaN
# 52       Обязательно знание автомобилей МАЗ, КАМАЗ, про...     NaN
# 55       Отдам щенка( кабель),помесь северной лайки и о...     NaN
# 61       Сделаю полную настройку и регулировку велосипе...   100.0
# 62       ООО "Производство Резервуарного Оборудования" ...     NaN
# 64       Выгрузка, погрузка\nПодать, поднести, принести...     NaN
# 70                                      Продам на запчасти     NaN
# 88       Идеально рабочий телефон! \nОписание смотрите ...     NaN
# 98       Волох А.С.  Основы управления действием взрыва...     NaN
# 116      Продам срочно ноутбук новый брали за 70 тыс по...     NaN
# 120      Дорогие девушки, предлагаю КАЧЕСТВЕННЫЕ и НЕДО...     NaN
# 126      ОТДАМ ЩЕНКОВ В ДОБРЫЕ РУКИ 🙏🏻 ПОДАРИТЕ МАЛЫШАМ...     NaN
# 130      Женщина 55 лет,РФ.Живу в Нижнем Новгороде. Без...     NaN
# 131      Заброска туристов на реки и озёра Лоухского ра...     NaN
# 140      Выполним строительство и отделку домов,бань,бе...     NaN
# 141      Выполним строительство домов,бань беседок гара...     NaN
# 142                          Продам фары. Цена договорная.     NaN
# 150      зарядка Nokia Универсальная AC-3E,подходит для...     NaN
# ...                                                    ...     ...
# 1043967  Изготавливаем качественный профнстил любой дли...     NaN
# 1043974  бампера на все машины .возможно в цвет .  возм...     NaN
# 1043983  меняю кабины КАМАЗ, МАЗ и другие запчасти ,б/у...     NaN
# 1043988  Продается экскаваторная навеска на МТЗ в отлич...     NaN
price1 = abs(test2.price_x - test2.price_y)/test2[["price_x", "price_y"]].min(axis=1)
location1 = 1*(test2.locationID_x == test2.locationID_y)

price1.fillna(price1.mean(), inplace=True) #data imputation using mean value

lat1 = abs(test2.lat_x - test2.lat_y)
lon1 = abs(test2.lon_x - test2.lon_y)
distance1 = (lat1**2 + lon1**2)**(.5)

description1 = 1*(test2.description_x == test2.description_y)
title1 = 1*(test2.title_x == test2.title_y)
category1 = 1*(test2.categoryID_x == test2.categoryID_y)
region1 = 1*(test2.regionID_x == test2.regionID_y)
parentCategory1 = 1*(test2.parentCategoryID_x == test2.parentCategoryID_y)


d1 = {'price': price1, 'location': location1, 
     'distance':distance1,
     'description':description1, 'title':title1, 
     'category': category1, 'region': region1, 'parentCategory': parentCategory1}
X1 = pd.DataFrame(data=d1)

# %%
X1.head()
# Out:
#           price  location  distance  description  title  category  region  \
# 0  61703.659451         1       0.0            0      0         1       1
# 1  61703.659451         1       0.0            0      0         1       1
# 2  61703.659451         1       0.0            0      1         1       1
# 3      1.653061         1       0.0            0      0         1       1
# 4      0.000000         1       0.0            1      0         1       1
#
#    parentCategory
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1

# %%
X1.isna().sum() #price有很多nan，需要
# Out:
# price             0
# location          0
# distance          0
# description       0
# title             0
# category          0
# region            0
# parentCategory    0
# dtype: int64

# %%
list(X1.columns)
# Out:
# ['price',
#  'location',
#  'distance',
#  'description',
#  'title',
#  'category',
#  'region',
#  'parentCategory']

# %%
X1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044196 entries, 0 to 1044195
# Data columns (total 8 columns):
# price             1044196 non-null float64
# location          1044196 non-null int64
# distance          1044196 non-null float64
# description       1044196 non-null int64
# title             1044196 non-null int64
# category          1044196 non-null int64
# region            1044196 non-null int64
# parentCategory    1044196 non-null int64
# dtypes: float64(2), int64(6)
# memory usage: 63.7 MB

# %% [markdown]
# We do not need imputation in the case.

# %%
## Imputation for whole dataframe

# %%
#from sklearn.impute import SimpleImputer
#import numpy as np
#imp_mean = SimpleImputer(missing_values=np.nan, strategy='mean')
#imp_mean.fit(X1)
#X2 = imp_mean.transform(X1)

# %%
#X2.shape

# %%
#X3 = pd.DataFrame(data = X2, columns=list(X1.columns))

# %%
#X3.head()

# %% [markdown]
# ## Prediction

# %%
pred_test = rfc.predict_proba(X1)[:,1]
pred_test = np.array(pred_test)

# %%
pred_test
# Out:
# array([0.04      , 0.04      , 0.78      , ..., 0.71062019, 0.17625459,
#        0.40618754])

# %%
len(pred_test)
# Out:
# 1044196

# %%
index = np.array(test2['id'].astype(np.int))

# %%
index
# Out:
# array([      0,       1,       2, ..., 1044193, 1044194, 1044195])

# %%
len(index)
# Out:
# 1044196

# %%
pred_test1 = {'id':index,'probability':pred_test}

# %%
pred_test2 = pd.DataFrame(pred_test1, columns =['id','probability'])

# %%
pred_test2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1044196 entries, 0 to 1044195
# Data columns (total 2 columns):
# id             1044196 non-null int64
# probability    1044196 non-null float64
# dtypes: float64(1), int64(1)
# memory usage: 15.9 MB

# %%
pred_test2.to_csv('/Users/jerry/Desktop/udemy courses/Kaggle数据分析/Avito Duplicate Ads Detection/prediction.csv',index=False)
